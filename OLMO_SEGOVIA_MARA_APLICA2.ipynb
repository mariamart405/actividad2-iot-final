# %% [markdown]
# # 🌐 Gráficas desde ThingSpeak (versión definitiva sin errores)
# Este cuaderno muestra gráficas embebidas directamente desde el canal `2960836` usando `IFrame`. Sin variables, sin errores de fusión, solo ejecuta ▶▶.

# %%
from IPython.display import IFrame

# %% [markdown]
# ### CO₂ (ppm)

# %%
IFrame('https://thingspeak.com/channels/2960836/charts/1?dynamic=true', width=700, height=350)

# %% [markdown]
# ### Ruido (dB)

# %%
IFrame('https://thingspeak.com/channels/2960836/charts/2?dynamic=true', width=700, height=350)

# %% [markdown]
# ### Luminosidad (lux)

# %%
IFrame('https://thingspeak.com/channels/2960836/charts/3?dynamic=true', width=700, height=350)

# %% [markdown]
# ### Presión atmosférica (hPa)

# %%
IFrame('https://thingspeak.com/channels/2960836/charts/4?dynamic=true', width=700, height=350)

# %% [markdown]
# ### Velocidad del viento (km/h)

# %%
IFrame('https://thingspeak.com/channels/2960836/charts/5?dynamic=true', width=700, height=350)
